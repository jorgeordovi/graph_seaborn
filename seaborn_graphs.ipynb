# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
data = {
    'Region': ['North', 'South', 'East', 'West', 'North','South', 'East', 'West'],
    'Month': ['January', 'January', 'January', 'January', 'February', 'February', 'February', 'February'],
    'Sales': [100,150,120,110,130,140,160,155]
}

# %%
df = pd.DataFrame(data)

sns.barplot(x='Region', y='Sales', data=df, hue='Month')
plt.title('Sales by Region & Month')
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='whitegrid')

plt.figure(figsize=(10,6))

sns.barplot(x='day', y='tip', data=tips, palette='Set2')

plt.title('Average tips by day of the week')
plt.xlabel('Days of the week')
plt.ylabel('Average Tip')

plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.histplot(tips['total_bill'], kde=True, bins=30, color='skyblue')
plt.title('Total count with KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')

plt.show()

# %%
import scipy as sp

# %%
sns.kdeplot(tips['total_bill'], fill=True, color='skyblue')
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(tips['total_bill'], fill=True, color='skyblue', bw_adjust=0.5)
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(tips['total_bill'], fill=True, color='skyblue', cumulative=True)
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(x=tips['total_bill'], y=tips['tip'], fill=True, cmap='Blues')
plt.title('Estimated Bi-variated of total tip distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='scatter', marginal_kws=dict(bins=15, fill=True))

plt.show()

# %%
# Regression Model

sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')

plt.show()

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='kde')

plt.show()

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='hex')

plt.show()

# %%
sns.swarmplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.swarmplot(data=tips, x='total_bill', y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips, x='day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex', dodge='size')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data=tips, x='total_bill', y='day', hue='sex', dodge='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.swarmplot(data=tips, x='total_bill', y='size', hue='sex', orient='h')
# Out:
# C:\Users\Work\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='total_bill', ylabel='size'>
# C:\Users\Work\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(
    data=tips.query("size in [2, 3, 5]"),
    x='total_bill',y='size', orient='h',
    native_scale=True,
)
# Out:
# <Axes: xlabel='total_bill', ylabel='size'>

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(x='day', y='tip', data=tips)

plt.title('Tip distribution per day')
plt.xlabel('Day')
plt.ylabel('Amount')

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.violinplot(x='day', y='tip', data=tips, inner=None, color='lightgray')

sns.swarmplot(x='day', y='tip', hue='sex', data=tips, palette='Set1', dodge=True)


plt.title('Tip disptributoion by day separated by sex')
plt.xlabel('Day')
plt.ylabel('Tip Amount')

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[:2], labels[:2])

plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=tips, x='total_bill', y='tip' )
plt.title('Relation between bill total and tip')
plt.xlabel('Day')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', order=2)
plt.title('Relation between bill total and tip')
plt.xlabel('Day')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', order=2)
plt.title('Relation between bill total and tip')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', logx=True)
plt.title('Relation between bill total and tip')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', robust=True)
plt.title('Relation between bill total and tip')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', ci=True)
plt.title('Relation between bill total and tip')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.regplot(data=tips, x='size', y='total_bill', x_jitter=.15)
plt.title('Relation between bill total and tip')
plt.xlabel('Tip')
plt.ylabel('Bill Amount')
# Out:
# Text(0, 0.5, 'Bill Amount')

# %%
import numpy as np
sns.regplot(data=tips, x='total_bill', y='size', x_bins=np.arange(30,60,1), order=2)
plt.title('Relation between bill total and tip')
plt.xlabel('Bill Amount')
plt.ylabel('size')
# Out:
# Text(0, 0.5, 'size')

# %%
sns.regplot(data=tips, x='total_bill', y='tip', order=2, ci=None, scatter_kws={'s':50}, line_kws={'color': 'red'})
plt.title('Relation between bill total and tip (Polinomic Regresion)')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(0, 0.5, 'Tip Amount')

# %%
sns.lmplot(
    data=tips, x='total_bill', y='tip',
    col='day', row='sex', height=3,
    facet_kws=dict(sharex=False, sharey=False)
)

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', height=6, aspect=1.5)
plt.title('Relation between bill total and tip (Polinomic Regresion)')
plt.xlabel('Tip')
plt.ylabel('Tip Amount')
# Out:
# Text(41.1845486111111, 0.5, 'Tip Amount')

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', height=4, aspect=0.8, col='day', robust=True, palette='coolwarm', markers=['o', 'x'], scatter_kws={'s':30, 'alpha': 0.7})
plt.subplots_adjust(top=0.9)
plt.suptitle('Relation between bill total and tip (Polinomic Regresion)')

plt.show()
# Out:
# C:\Users\Work\anaconda3\lib\site-packages\statsmodels\robust\robust_linear_model.py:288: ConvergenceWarning: Estimated scale is 0.0 indicating that the most last iteration produced a perfect fit of the weighted data.
#   warnings.warn('Estimated scale is 0.0 indicating that the most'
# C:\Users\Work\anaconda3\lib\site-packages\statsmodels\robust\robust_linear_model.py:288: ConvergenceWarning: Estimated scale is 0.0 indicating that the most last iteration produced a perfect fit of the weighted data.
#   warnings.warn('Estimated scale is 0.0 indicating that the most'
# C:\Users\Work\anaconda3\lib\site-packages\statsmodels\robust\robust_linear_model.py:288: ConvergenceWarning: Estimated scale is 0.0 indicating that the most last iteration produced a perfect fit of the weighted data.
#   warnings.warn('Estimated scale is 0.0 indicating that the most'
# ...

# %%
plt.figure(figsize=(8,6))
sns.residplot(x='total_bill', y='tip', data=tips)

plt.title('Residues of regresion between Total bill and Tip')
plt.xlabel('Total bill')
plt.ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
plt.figure(figsize=(8,6))
sns.residplot(x='total_bill', y='tip', data=tips, lowess=True, scatter_kws={'alpha': 0.5}, line_kws={'color': 'red', 'lw': 2})

plt.title('Residues of regresion between Total bill and Tip (Soft lowers)')
plt.xlabel('Total bill')
plt.ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
titanic = sns.load_dataset('titanic')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
titanic =titanic.dropna(subset=['age', 'sex', 'embarked'])

titanic['sex'] = titanic['sex'].map({'male': 0, 'female': 1})
titanic['embarked'] = titanic['embarked'].map({'C': 0, 'Q': 1, 'S': 2})

X = titanic[['pclass','sex','age','sibsp','parch','fare','embarked']]
y = titanic['survived']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", linewidths=.5, linecolor='black', cbar_kws={'label': 'Number of cases'}, xticklabels=['Not survided'])

plt.title('Confusion Matrix of Regression Model')
plt.xlabel('Prediction')
plt.ylabel('Reality')

plt.show()

# %%
flights = sns.load_dataset('flights')
flights_pivot = flights.pivot(index='month', columns='year', values='passengers')
sns.clustermap(flights_pivot, cmap="YlGnBu", linewidth=.5, linecolor='black', cbar_kws={'label': 'Number of Passengers'}, annot=True, fmt='d')
plt.title('Clustermap of Passenger Number by Month and Year')
plt.show()

# %%
sns.set_theme(style='darkgrid')
data= sns.load_dataset('tips')
sns.scatterplot(data=data, x="total_bill", y='tip', hue='day')
plt.show()

# %%
sns.color_palette('cubehelix')
# Out:
# [(0.10231025194333628, 0.13952898866828906, 0.2560120319409181),
#  (0.10594361078604106, 0.3809739011595331, 0.27015111282899046),
#  (0.4106130272672762, 0.48044780541672255, 0.1891154277778484),
#  (0.7829183382530567, 0.48158303462490826, 0.48672451968362596),
#  (0.8046168329276406, 0.6365733569301846, 0.8796578402926125),
#  (0.7775608374378459, 0.8840392521212448, 0.9452007992345052)]

# %%
palettes = ["deep", "muted", "bright", "pastel", "dark", "colorblind", "Blues", "BuGn", "PuBu", "OrRd", "PuBuGn", "PuRd", "Purples", "RdPu", "Reds", "YlGn", "YlGnBu","afmhot","autumn", "binary", "bone","cool","copper", "cubehelix","flag","gist_gray", "gist_heat", "gist_ncar","gist_rainbow"]
n = len(palettes)
fig, axes = plt.subplots(ncols=1, nrows=n, figsize=(8, 2*n), dpi=80)

for ax, palette in zip(axes, palettes):
    colors = sns.color_palette(palette)
    n_colors = len(colors)
    ax.imshow([colors], aspect='auto')
    ax.set_xticks(range(n_colors))
    ax.set_xticklabels(range(1, n_colors+1))
    ax.set_yticks([])
    ax.set_title(palette, fontsize=12, pad=5)

plt.tight_layout()
plt.show()
