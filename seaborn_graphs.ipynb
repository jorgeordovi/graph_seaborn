# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
data = {
    'Region': ['North', 'South', 'East', 'West', 'North','South', 'East', 'West'],
    'Month': ['January', 'January', 'January', 'January', 'February', 'February', 'February', 'February'],
    'Sales': [100,150,120,110,130,140,160,155]
}

# %%
df = pd.DataFrame(data)

sns.barplot(x='Region', y='Sales', data=df, hue='Month')
plt.title('Sales by Region & Month')
plt.show()

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style='whitegrid')

plt.figure(figsize=(10,6))

sns.barplot(x='day', y='tip', data=tips, palette='Set2')

plt.title('Average tips by day of the week')
plt.xlabel('Days of the week')
plt.ylabel('Average Tip')

plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.histplot(tips['total_bill'], kde=True, bins=30, color='skyblue')
plt.title('Total count with KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')

plt.show()

# %%
import scipy as sp

# %%
sns.kdeplot(tips['total_bill'], shade=True, color='skyblue')
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# C:\Users\Work\AppData\Local\Temp\ipykernel_7788\514995873.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True, color='skyblue')
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(tips['total_bill'], shade=True, color='skyblue', bw_adjust=0.5)
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# C:\Users\Work\AppData\Local\Temp\ipykernel_7788\1455454188.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True, color='skyblue', bw_adjust=0.5)
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(tips['total_bill'], shade=True, color='skyblue', cumulative=True)
plt.title('Estimated nucleus density KDE distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# C:\Users\Work\AppData\Local\Temp\ipykernel_7788\1205687173.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True, color='skyblue', cumulative=True)
# Text(0, 0.5, 'Frequency')

# %%
sns.kdeplot(x=tips['total_bill'], y=tips['tip'], fill=True, cmap='Blues')
plt.title('Estimated Bi-variated of total tip distribution')
plt.xlabel('Total count in ($)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
